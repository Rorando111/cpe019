# %% [markdown]
# <a href="https://colab.research.google.com/github/Rorando111/cpe019/blob/main/Hands_on_Activity_4_1_Advanced_Data_Analytics_and_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: <br> Rolando F. Celeste
# Course and Section: <br> CPE-019, CPE32S9
# Date of Submission: <br> 01/31/2024
# Instructor: <br> Engr. Roman Richard
#
# # Hands-on Activity 4.1: Advanced Data Analytics and Machine Learning
#
# Create a jupyter notebook for this activity. (Present it well)
# Use the titanic dataset, which you can download here: titanic_test.csv Download titanic_test.csv  and titanic_train.csv Download titanic_train.csv
#
# PART 1: Do the following objectives:
#
# Part 1: Import the Libraries and Data
#
# Part 2: Plot the Data
#
# Part 3: Perform Simple Linear Regression on the SURVIVAL feature column (you can check the internet on how you can perform simple linear regression)
#
# PART 2: Download this PDF and perform the DECISION TREE classification activity: 4.1.3.5 Lab - Decision Tree Classification.pdf Download 4.1.3.5 Lab - Decision Tree Classification.pdf
# Use only one jupyter notebook for these 2 sets of activities.
# Only PDFs should be submitted. (While on jupyter notebook, press CTRL + P, and click save as PDF)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part 1: Import the Libraries and Data

# %%
tc_test = '/content/titanic_test.csv'
tc_test_frame = pd.read_csv(tc_test)
tc_test_frame.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
tc_test_frame.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
tc_train = '/content/titanic_train.csv'
tc_train_frame = pd.read_csv(tc_train)
tc_train_frame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tc_train_frame.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 2. Part 2: Plot the Data

# %%
sns.barplot(x='Pclass', y='Fare', data=tc_test_frame)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
tc_test_frame.corr(method='pearson').round(3)
# Out:
# <ipython-input-84-21b1b9e1b332>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc_test_frame.corr(method='pearson').round(3)
#              PassengerId  Pclass    Age  SibSp  Parch   Fare
# PassengerId        1.000  -0.027 -0.034  0.004  0.043  0.008
# Pclass            -0.027   1.000 -0.492  0.001  0.019 -0.577
# Age               -0.034  -0.492  1.000 -0.092 -0.061  0.338
# SibSp              0.004   0.001 -0.092  1.000  0.307  0.172
# Parch              0.043   0.019 -0.061  0.307  1.000  0.230
# Fare               0.008  -0.577  0.338  0.172  0.230  1.000

# %%
test_corr = tc_test_frame.corr().round(2)
sns.heatmap(test_corr, annot = True)
# Out:
# <ipython-input-100-1c65654c1e05>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   test_corr = tc_test_frame.corr().round(2)
# <Axes: >

# %%
sns.barplot(x='Pclass', y='Survived', data=tc_train_frame)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ## 3. Part 3: Perform Simple Linear Regression on the SURVIVAL feature column (you can check the internet on how you can perform simple linear regression)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=tc_train_frame)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
x = tc_train_frame.Survived.head(10)
y = tc_train_frame.Age.head(10)
n = np.size(x)

x_mean = np.mean(x)
y_mean = np.mean(y)
x_mean,y_mean

Sxy = np.sum(x*y)- n*x_mean*y_mean
Sxx = np.sum(x*x)-n*x_mean*x_mean

b1 = Sxy/Sxx
b0 = y_mean-b1*x_mean

y_pred = b1 * x + b0

plt.scatter(x, y, color = 'red')
plt.plot(x, y_pred, color = 'green')
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
